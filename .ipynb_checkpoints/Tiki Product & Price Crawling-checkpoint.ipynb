# %% [markdown]
# # Tiki Product & Price Crawling

# %%
# Import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Create array for product title & price
title = []
price = []

# %%
# Web scrap function
def scrap(WebUrl):
    # Web URL
    url = WebUrl
    
    # Plain HTML code
    plain = requests.get(url).text
    
    # Parser
    s = BeautifulSoup(plain, "html.parser")
    
    # Find and add product titles to array
    for i in s.findAll('p',{'class':'title'}):
        title.append(i.text.strip())
        
    # Find and add product price to aray    
    for i in s.findAll('span',{'class':'final-price'}):
        price.append(i.text.split()[0])

# %%
# Run Web scrap function
scrap('https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=mega-menu')

# %%
# Create dataframe from arrays
data = {'product':title,'price':price}
df = pd.DataFrame(data)
df
# Out:
#                                             product       price
# 0             Điện Thoại Samsung Galaxy S10 Plus...  17.810.000
# 1      Điện Thoại Xiaomi Redmi 6 (3/32GB) - Hàng...   2.290.000
# 2     Điện Thoại iPhone XR (64GB) - Hàng Chính Hãng  17.960.000
# 3     Điện Thoại iPhone XS Max 64GB - Hàng Chính...  27.990.000
# 4    Điện Thoại OPPO A3s (16GB/2GB) - Hàng Chính...   2.720.000
# 5       Điện Thoại Nokia 105 Single Sim (2017) -...     327.000
# 6         iPad WiFi 32GB New 2018 - Hàng Chính Hãng   7.150.000
# 7    Máy Đọc Sách Kindle Paperwhite 2018 (7th) -...   2.490.000
# 8      Điện Thoại Xiaomi Redmi 6A - Hàng Chính Hãng   1.890.000
# 9      Điện Thoại Trẻ Em MKIDS - Hàng Chính Hãng...     270.000
# 10   Điện Thoại Xiaomi Redmi Note 7 (3GB/32GB) -...   3.880.000
# 11           Điện Thoại Nokia 3.1 - Hàng Chính Hãng   1.760.000
# 12      Điện Thoại Nokia 130 2017 - Hàng Chính Hãng     459.000
# 13       Điện Thoại Nokia 8110 4G - Hàng Chính Hãng     749.000
# 14        iPad Mini 5 Wi-Fi 64GB -  Hàng Chính Hãng   9.890.000
# 15    Điện Thoại Nokia 106 Dual Sim - Hàng Chính...     358.000
# 16      Điện Thoại Nokia 5.1 Plus - Hàng Chính Hãng   2.870.000
# 17             Máy Đọc Sách Kindle 2018 (8th) - Đen   1.950.000
# 18     Điện Thoại Xiaomi Mi Mix 2 (Black) - Hàng...  12.990.000
# 19   Máy Đọc Sách Kindle Paperwhite 2018 (7th) -...   2.590.000
